# %%
import requests
import pandas as pd
import json
import config
import msal
from datetime import datetime, timedelta
from dateutil import parser

# %%
def powerBIPostDataset(group_id, data_types, token):
    # Create the URL endpoint for the REST API call.
    powerBIApiUrl = "https://api.powerbi.com/v1.0/myorg/groups/" + group_id + "/datasets"
    headers = {'Authorization': 'Bearer ' + token,
               'Content-Type': 'application/json'}
    # Post the data to the Power BI API endpoint
    response = requests.post(powerBIApiUrl, headers=headers, json=data_types)
    return response

def powerBIDeleteDataset(group_id, dataset_id, token):
    powerBIApiURl = f"https://api.powerbi.com/v1.0/myorg/groups/{group_id}/datasets/{dataset_id}"
    headers = {'Authorization': 'Bearer ' + token,
                'Content-Type': 'application/json'}
    response = requests.delete(powerBIApiURl, headers=headers)
    return response

def powerBIGetDatasetID(group_id, token):
    powerBIApiUrl = "https://api.powerbi.com/v1.0/myorg/groups/" + group_id + "/datasets"
    headers = {'Authorization': 'Bearer ' + token,
               'Content-Type': 'application/json'}
    response = requests.get(powerBIApiUrl, headers=headers)
    response_json = response.json()
    dataset_id = response_json['value'][0]['id']
    dataset_name = response_json['value'][0]['name']
    return dataset_id, dataset_name

def powerBIPutTable(group_id, dataset_id, put_table_name, put_request, token):
    # URL encode the table name
    put_table_name = put_table_name.replace(" ", "%20")
    # Construct the URL
    powerBIAPIUrl = f"https://api.powerbi.com/v1.0/myorg/groups/{group_id}/datasets/{dataset_id}/tables/{put_table_name}"
    headers = {
        'Authorization': 'Bearer ' + token,
        'Content-Type': 'application/json'
    }
    response = requests.put(powerBIAPIUrl, headers=headers, json=put_request)
    return response
    
def powerBIPostRows(group_id, dataset_id, table_name, rows_request, token):
    table_name = table_name.replace(" ", "%20")
    powerBIApiUrl = f"https://api.powerbi.com/v1.0/myorg/groups/{group_id}/datasets/{dataset_id}/tables/{table_name}/rows"
    headers = {'Authorization': 'Bearer ' + token,
            'Content-Type': 'application/json'}
    # Post the rows
    response = requests.post(powerBIApiUrl, headers=headers, json=rows_request)
    return response

# %%
client_id = ""
client_secret = ""
tenant_id = ""

url2 = f"https://login.microsoftonline.com/{tenant_id}/"

app = msal.ConfidentialClientApplication(client_id=client_id, client_credential=client_secret, authority = url2)
scope = ["https://analysis.windows.net/powerbi/api/.default"]

# Acquire token using client credentials (i.e., service principal)
result = app.acquire_token_for_client(scopes=scope)
token = result['access_token']

# %%
df = pd.read_csv("modified_lighter_311.csv")
df.head()

# %%
# Update zipcode column to be a string and pad with leading zeros
df['location_zipcode'] = df['location_zipcode'].astype(str).str.zfill(5)
#df['latitude'] = df['latitude'].astype(str)
#df['longitude'] = df['longitude'].astype(str)

# %%
# drop submitted_photo and closed_photo columns
df = df.drop(columns=['submitted_photo', 'closed_photo'])

# %%
def closure_reason(reason):
    # Right strip the reason
    reason = reason.strip()
    if 'resolved' in reason.lower():
        return 'resolved'
    elif 'noted' in reason.lower():
        return 'noted'
    elif 'automation' in reason.lower():
        return 'bulk item automation'
    elif 'duplicate' in reason.lower():
        return 'duplicate'
    elif 'invalid' in reason.lower() or "invaild" in reason.lower():
        return 'invalid'
    elif 'viocor' in reason.lower():
        return 'viocor'
    elif 'vioiss' in reason.lower():
        return  'vioiss'
    elif 'adclsd' in reason.lower():
        return 'adclsd'
    elif 'permis' in reason.lower():
        return 'permis'
    elif 'corr' in reason.lower():
        return 'corr'
    elif 'roa' in reason.lower() or "referred to external agency" in reason.lower() or "per " in reason.lower():
        return 'roa'
    elif "" == reason.split(":")[-1] or len(reason.split(":")[-1]) <=6:
        return 'empty'
    elif 'internal case' in reason.lower():
        return 'internal case'
    elif 'novio' in reason.lower():
        return 'novio'
    elif 'nobase' in reason.lower():
        return 'nobase'
    elif "noacc" in reason.lower() or "private" in reason.lower():
        return 'noacc'
    elif "CLOSED" in reason or "AVRS" in reason or "close" in reason.lower().split(":")[-1]:
        return 'closed'
    elif 'violfnd' in reason.lower():
        return 'violfnd'
    elif 'reinsp' in reason.lower():
        return 'reinsp'
    elif 'tfa' in reason.lower():
        return 'tfa'
    elif "e-form" in reason.lower() or "eform" in reason.lower() or "e form" in reason.lower():
        return 'eform'    
    elif "resubmitted" in reason.lower():
        return 'resubmitted'
    elif "cancel" in reason.lower():
        return 'cancel'
    elif "ticket" in reason.lower():
        return 'ticket'
    elif "tsop" in reason.lower():
        return 'tsop'
    else:
        return 'other'

# update closure_reason column
df['closure_reason'] = df['closure_reason'].apply(closure_reason)

# %%
# Convert open_dt, closed_dt, and sla_target_dt to datetime
df['open_dt'] = pd.to_datetime(df['open_dt'])
df['closed_dt'] = pd.to_datetime(df['closed_dt'])
df['sla_target_dt'] = pd.to_datetime(df['sla_target_dt'])

# convert resolution time to timedelta
df['resolution_time'] = df['closed_dt'] - df['open_dt']
df.loc[df['resolution_time'] < timedelta(0),'resolution_time'] = timedelta(seconds=0) # replace negative resolution times with 0
df['resolution_time'] = df['resolution_time'].dt.total_seconds() / 86400

# Convert open_dt to open_year, open_month, open_day, open_hour, open_minute, open_dayofweek, open_dayofyear, open_weekofyear, open_quarter
df['open_year'] = df['open_dt'].dt.year
df['open_month'] = df['open_dt'].dt.month
df['open_day'] = df['open_dt'].dt.day
df['open_hour'] = df['open_dt'].dt.hour
df['open_minute'] = df['open_dt'].dt.minute
df['open_dayofweek'] = df['open_dt'].dt.dayofweek
df['open_dayofyear'] = df['open_dt'].dt.dayofyear
df['open_quarter'] = df['open_dt'].dt.quarter

# %%
# Turn DF into a list of dictionaries
pbi_package = df.to_dict('records')

# Get column types
df_types = df.dtypes.to_dict()

# %%
for key in df_types:
    print(key, df_types[key])

# %%
pbi_type_map = {
    'object': 'string',
    'int64': 'Int64',
    'int32': 'Int64',
    'float64': 'Double',
    'bool': 'bool',
    'datetime64[ns]': 'Datetime'
}

# Convert the types
pbi_types = {}

for col in df_types.keys():
    pbi_types[col] = pbi_type_map[str(df_types[col])]

pbi_types
# Out:
# {'case_enquiry_id': 'Int64',
#  'open_dt': 'Datetime',
#  'sla_target_dt': 'Datetime',
#  'closed_dt': 'Datetime',
#  'on_time': 'string',
#  'case_status': 'string',
#  'closure_reason': 'string',
#  'case_title': 'string',
#  'subject': 'string',
#  'reason': 'string',
#  'type': 'string',
#  'queue': 'string',
#  'department': 'string',
#  'fire_district': 'string',
#  'pwd_district': 'string',
#  'city_council_district': 'string',
#  'police_district': 'string',
#  'neighborhood': 'string',
#  'neighborhood_services_district': 'string',
#  'ward': 'string',
#  'precinct': 'string',
#  'location_zipcode': 'string',
#  'latitude': 'Double',
#  'longitude': 'Double',
#  'source': 'string',
#  'resolution_time': 'Double',
#  'open_year': 'Int64',
#  'open_month': 'Int64',
#  'open_day': 'Int64',
#  'open_hour': 'Int64',
#  'open_minute': 'Int64',
#  'open_dayofweek': 'Int64',
#  'open_dayofyear': 'Int64',
#  'open_quarter': 'Int64'}

# %%
dataset_build_request = {}
dataset_name = "311"
table_name = "base"
dataset_build_request['name'] = dataset_name
dataset_build_request['defaultMode'] = 'Push'
dataset_build_request['tables'] = [{'name': table_name, 'columns': []}]
# Populate columns
for col in pbi_types.keys():
    dataset_build_request['tables'][0]['columns'] += [{'name': col, 'dataType': pbi_types[col]}]

# %%
group_id = "f36042ed-0cc0-4837-87fc-856b4b4cc901"

# Delete the dataset if it already exists
try:
    dataset_id, dataset_name = powerBIGetDatasetID(group_id, token)
    response = powerBIDeleteDataset(group_id, dataset_id, token)
    print("Dataset Deleted")
except:
    print("Dataset does not exist")
# Out:
# Dataset does not exist

# %%
try:
    dataset_id, dataset_name = powerBIGetDatasetID(group_id, token)
    # Put the table
    put_request = dataset_build_request['tables'][0]
    put_table_name = put_request['name']
    powerBIPutTable(group_id, dataset_id, put_table_name, put_request, token)
    print("Table Updated")
except:
    # Post the dataset
    response = powerBIPostDataset(group_id, dataset_build_request, token)
    print("Table Posted")
    dataset_id, dataset_name = powerBIGetDatasetID(group_id, token)
# Out:
# Table Posted

# %%
# save df to csv
df.to_csv("modified_dates_311.csv", index=False)

# %%
# Apply pbi types to package
for col in pbi_types.keys():
    for row in pbi_package:
        if pbi_types[col] == 'Datetime':
            try:
                row[col] = row[col].strftime('%Y-%m-%dT%H:%M:%SZ')
            except:
                row[col] = None
        elif pbi_types[col] == 'Int64':
            try:
                row[col] = int(row[col])
            except:
                row[col] = 0

# %%
rows_request = {}
rows_request['rows'] = pbi_package
rows_request
# Out:
# {'rows': [{'case_enquiry_id': 101000295613,
#    'open_dt': '2011-06-30T21:32:33Z',
#    'sla_target_dt': '2011-07-14T21:32:32Z',
#    'closed_dt': '2011-07-01T01:06:58Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Street Light Outages',
#    'subject': 'Public Works Department',
#    'reason': 'Street Lights',
#    'type': 'Street Light Outages',
#    'queue': 'PWDx_Street Light Outages',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'B3',
#    'neighborhood': 'Greater Mattapan',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 17',
#    'precinct': '1714',
#    'location_zipcode': '02126',
#    'latitude': 42.27154416019889,
#    'longitude': -71.07722102041515,
#    'source': 'Employee Generated',
#    'resolution_time': 0.14890046296296297,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 21,
#    'open_minute': 32,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295614,
#    'open_dt': '2011-06-30T22:18:31Z',
#    'sla_target_dt': '2011-07-04T22:18:31Z',
#    'closed_dt': '2011-07-01T02:12:43Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '5',
#    'police_district': 'E5',
#    'neighborhood': 'Roslindale',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 20',
#    'precinct': '2008',
#    'location_zipcode': '02131',
#    'latitude': 42.28384964675283,
#    'longitude': -71.14474080817594,
#    'source': 'Self Service',
#    'resolution_time': 0.1626388888888889,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 22,
#    'open_minute': 18,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295615,
#    'open_dt': '2011-06-30T22:28:04Z',
#    'sla_target_dt': '2011-08-14T22:28:04Z',
#    'closed_dt': '2011-08-01T11:21:46Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'New Sign  Crosswalk or Pavement Marking',
#    'subject': 'Transportation - Traffic Division',
#    'reason': 'Signs & Signals',
#    'type': 'New Sign  Crosswalk or Pavement Marking',
#    'queue': 'BTDT_Engineering_New Sign and Pavement Marking Requests',
#    'department': 'BTDT',
#    'fire_district': nan,
#    'pwd_district': '06',
#    'city_council_district': '6',
#    'police_district': 'E5',
#    'neighborhood': 'West Roxbury',
#    'neighborhood_services_district': '12',
#    'ward': 'Ward 20',
#    'precinct': '2017',
#    'location_zipcode': '02132',
#    'latitude': 42.300277970295845,
#    'longitude': -71.16980478173973,
#    'source': 'Self Service',
#    'resolution_time': 31.53729166666667,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 22,
#    'open_minute': 28,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295616,
#    'open_dt': '2011-06-30T23:03:48Z',
#    'sla_target_dt': '2011-07-14T23:03:48Z',
#    'closed_dt': '2011-07-22T12:13:45Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Street Light Outages',
#    'subject': 'Public Works Department',
#    'reason': 'Street Lights',
#    'type': 'Street Light Outages',
#    'queue': 'PWDx_Street Light_Pending_Contractor (Internal)',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1816',
#    'location_zipcode': '02136',
#    'latitude': 42.24963961259866,
#    'longitude': -71.11563081862258,
#    'source': 'Self Service',
#    'resolution_time': 21.54857638888889,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 23,
#    'open_minute': 3,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295617,
#    'open_dt': '2011-06-30T23:12:31Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T02:12:38Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Highway Maintenance',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Highway Maintenance',
#    'queue': 'PWDx_District 03: North Dorchester',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '03',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 13',
#    'precinct': '1309',
#    'location_zipcode': '02125',
#    'latitude': 42.31443571025152,
#    'longitude': -71.05687844130581,
#    'source': 'Constituent Call',
#    'resolution_time': 0.12508101851851852,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 23,
#    'open_minute': 12,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295618,
#    'open_dt': '2011-06-30T23:43:07Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-05T05:16:10Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'noted',
#    'case_title': 'Notification',
#    'subject': "Mayor's 24 Hour Hotline",
#    'reason': 'Notification',
#    'type': 'Notification',
#    'queue': 'INFO09_Current Events',
#    'department': 'INFO',
#    'fire_district': '9',
#    'pwd_district': '10A',
#    'city_council_district': '6',
#    'police_district': 'E13',
#    'neighborhood': 'Jamaica Plain',
#    'neighborhood_services_district': '11',
#    'ward': 'Ward 10',
#    'precinct': '1006',
#    'location_zipcode': '02130',
#    'latitude': 42.32428958688874,
#    'longitude': -71.10603063017552,
#    'source': 'Constituent Call',
#    'resolution_time': 4.231284722222222,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 23,
#    'open_minute': 43,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295619,
#    'open_dt': '2011-07-01T01:35:41Z',
#    'sla_target_dt': '2011-08-15T01:35:41Z',
#    'closed_dt': '2011-10-17T08:33:28Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'noted',
#    'case_title': 'New Sign  Crosswalk or Pavement Marking',
#    'subject': 'Transportation - Traffic Division',
#    'reason': 'Signs & Signals',
#    'type': 'New Sign  Crosswalk or Pavement Marking',
#    'queue': 'BTDT_Pavement Marking_Maintenance',
#    'department': 'BTDT',
#    'fire_district': '4',
#    'pwd_district': '10A',
#    'city_council_district': '8',
#    'police_district': 'D4',
#    'neighborhood': 'Fenway / Kenmore / Audubon Circle / Longwood',
#    'neighborhood_services_district': '14',
#    'ward': 'Ward 21',
#    'precinct': '2102',
#    'location_zipcode': '02215',
#    'latitude': 42.34712657790324,
#    'longitude': -71.10333422171043,
#    'source': 'Self Service',
#    'resolution_time': 108.29012731481481,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 1,
#    'open_minute': 35,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295620,
#    'open_dt': '2011-07-01T02:24:38Z',
#    'sla_target_dt': '2011-07-15T02:24:38Z',
#    'closed_dt': '2011-08-23T06:33:03Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Street Light Outages',
#    'subject': 'Public Works Department',
#    'reason': 'Street Lights',
#    'type': 'Street Light Outages',
#    'queue': 'PWDx_Street Light_Pending_Contractor (Internal)',
#    'department': 'PWDx',
#    'fire_district': '9',
#    'pwd_district': '10B',
#    'city_council_district': '7',
#    'police_district': 'E13',
#    'neighborhood': 'Roxbury',
#    'neighborhood_services_district': '13',
#    'ward': 'Ward 11',
#    'precinct': '1103',
#    'location_zipcode': '02119',
#    'latitude': 42.31730593338646,
#    'longitude': -71.09677136472,
#    'source': 'Constituent Call',
#    'resolution_time': 53.17251157407407,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 2,
#    'open_minute': 24,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295622,
#    'open_dt': '2011-07-01T02:44:50Z',
#    'sla_target_dt': '2011-07-04T02:44:49Z',
#    'closed_dt': '2011-07-01T02:44:55Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pick up Dead Animal',
#    'subject': 'Public Works Department',
#    'reason': 'Street Cleaning',
#    'type': 'Pick up Dead Animal',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1602',
#    'location_zipcode': '02122',
#    'latitude': 42.30201951528505,
#    'longitude': -71.05191055807035,
#    'source': 'Employee Generated',
#    'resolution_time': 5.787037037037037e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 2,
#    'open_minute': 44,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295624,
#    'open_dt': '2011-07-01T02:50:25Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T02:50:29Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Highway Maintenance',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Highway Maintenance',
#    'queue': 'PWDx_District 03: North Dorchester',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '03',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 13',
#    'precinct': '1309',
#    'location_zipcode': '02125',
#    'latitude': 42.3145335217776,
#    'longitude': -71.05705354143386,
#    'source': 'Employee Generated',
#    'resolution_time': 4.6296296296296294e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 2,
#    'open_minute': 50,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295625,
#    'open_dt': '2011-07-01T02:55:10Z',
#    'sla_target_dt': '2011-07-05T02:55:10Z',
#    'closed_dt': '2011-07-05T05:42:04Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Sticker Request',
#    'subject': 'Public Works Department',
#    'reason': 'Recycling',
#    'type': 'Sticker Request',
#    'queue': 'PWDx_Sticker Request',
#    'department': 'PWDx',
#    'fire_district': '6',
#    'pwd_district': '05',
#    'city_council_district': '2',
#    'police_district': 'C6',
#    'neighborhood': 'South Boston / South Boston Waterfront',
#    'neighborhood_services_district': '5',
#    'ward': 'Ward 7',
#    'precinct': '0701',
#    'location_zipcode': '02127',
#    'latitude': 42.33045249395599,
#    'longitude': -71.03708646139529,
#    'source': 'Self Service',
#    'resolution_time': 4.1159027777777775,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 2,
#    'open_minute': 55,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295627,
#    'open_dt': '2011-07-01T03:14:36Z',
#    'sla_target_dt': '2011-07-05T03:14:36Z',
#    'closed_dt': '2011-07-11T08:13:25Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Utility Call-In',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Utility Call-In',
#    'queue': 'PWDx_Utility Call-In',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1817',
#    'location_zipcode': '02136',
#    'latitude': 42.24487964311917,
#    'longitude': -71.12043083413081,
#    'source': 'Constituent Call',
#    'resolution_time': 10.207511574074074,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 14,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295628,
#    'open_dt': '2011-07-01T03:16:44Z',
#    'sla_target_dt': '2011-07-31T03:16:44Z',
#    'closed_dt': '2011-07-08T06:44:08Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'vioiss',
#    'case_title': 'Rodent Activity',
#    'subject': 'Inspectional Services',
#    'reason': 'Environmental Services',
#    'type': 'Rodent Activity',
#    'queue': 'ISD_Environmental Services (INTERNAL)',
#    'department': 'ISD',
#    'fire_district': '4',
#    'pwd_district': '1C',
#    'city_council_district': '2',
#    'police_district': 'A1',
#    'neighborhood': 'Back Bay',
#    'neighborhood_services_district': '6',
#    'ward': 'Ward 5',
#    'precinct': '0501',
#    'location_zipcode': '02116',
#    'latitude': 42.34874753263342,
#    'longitude': -71.0674934886141,
#    'source': 'Constituent Call',
#    'resolution_time': 7.144027777777778,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 16,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295629,
#    'open_dt': '2011-07-01T03:28:09Z',
#    'sla_target_dt': '2011-07-05T03:28:08Z',
#    'closed_dt': '2011-07-08T06:26:28Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Sidewalk Repair (Make Safe)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Sidewalk Repair (Make Safe)',
#    'queue': 'PWDx_Highway Construction',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '6',
#    'police_district': 'E5',
#    'neighborhood': 'West Roxbury',
#    'neighborhood_services_district': '12',
#    'ward': 'Ward 20',
#    'precinct': '2017',
#    'location_zipcode': '02132',
#    'latitude': 42.28759087384675,
#    'longitude': -71.16863452256548,
#    'source': 'Constituent Call',
#    'resolution_time': 7.123831018518518,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 28,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295630,
#    'open_dt': '2011-07-01T03:31:50Z',
#    'sla_target_dt': '2011-07-05T03:31:46Z',
#    'closed_dt': '2011-07-01T08:00:42Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Missed Recycling: District 06',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Missed Trash/Recycling/Yard Waste/Bulk Item',
#    'queue': 'PWDx_Missed Trash\\Recycling\\Yard Waste\\Bulk Item',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '5',
#    'police_district': 'E5',
#    'neighborhood': 'Roslindale',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1810',
#    'location_zipcode': '02131',
#    'latitude': 42.28184962688987,
#    'longitude': -71.13060078096619,
#    'source': 'Employee Generated',
#    'resolution_time': 0.18671296296296297,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 31,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295631,
#    'open_dt': '2011-07-01T03:33:45Z',
#    'sla_target_dt': '2011-07-05T03:33:44Z',
#    'closed_dt': '2011-07-01T03:42:58Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'invalid',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '10B',
#    'city_council_district': '7',
#    'police_district': 'B2',
#    'neighborhood': 'Roxbury',
#    'neighborhood_services_district': '13',
#    'ward': 'Ward 9',
#    'precinct': '0905',
#    'location_zipcode': '02119',
#    'latitude': 42.327909564852966,
#    'longitude': -71.08997058599672,
#    'source': 'Employee Generated',
#    'resolution_time': 0.006400462962962963,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 33,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295632,
#    'open_dt': '2011-07-01T03:34:19Z',
#    'sla_target_dt': '2011-07-29T03:34:16Z',
#    'closed_dt': '2011-07-22T11:43:34Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Request for Recycling Cart',
#    'subject': 'Public Works Department',
#    'reason': 'Recycling',
#    'type': 'Request for Recycling Cart',
#    'queue': 'PWDx_Recycling',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '10B',
#    'city_council_district': '7',
#    'police_district': 'B2',
#    'neighborhood': 'Roxbury',
#    'neighborhood_services_district': '13',
#    'ward': 'Ward 9',
#    'precinct': '0905',
#    'location_zipcode': '02119',
#    'latitude': 42.327909564852966,
#    'longitude': -71.08997058599672,
#    'source': 'Employee Generated',
#    'resolution_time': 21.339756944444446,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 34,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295633,
#    'open_dt': '2011-07-01T03:36:03Z',
#    'sla_target_dt': '2011-07-05T03:36:02Z',
#    'closed_dt': '2011-07-01T03:36:43Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '9',
#    'pwd_district': '06',
#    'city_council_district': '6',
#    'police_district': 'E5',
#    'neighborhood': 'West Roxbury',
#    'neighborhood_services_district': '12',
#    'ward': 'Ward 20',
#    'precinct': '2019',
#    'location_zipcode': '02132',
#    'latitude': 42.29167965472856,
#    'longitude': -71.1520008070818,
#    'source': 'Employee Generated',
#    'resolution_time': 0.000462962962962963,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 36,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295634,
#    'open_dt': '2011-07-01T03:37:17Z',
#    'sla_target_dt': '2011-07-05T03:37:16Z',
#    'closed_dt': '2011-07-01T03:37:39Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '6',
#    'pwd_district': '05',
#    'city_council_district': '2',
#    'police_district': 'C6',
#    'neighborhood': 'South Boston / South Boston Waterfront',
#    'neighborhood_services_district': '5',
#    'ward': '06',
#    'precinct': '0606',
#    'location_zipcode': '02127',
#    'latitude': 42.334630562886446,
#    'longitude': -71.03635056820346,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0002546296296296296,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 37,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295635,
#    'open_dt': '2011-07-01T03:38:25Z',
#    'sla_target_dt': '2011-07-05T03:38:24Z',
#    'closed_dt': '2011-07-01T03:38:44Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '11',
#    'pwd_district': '04',
#    'city_council_district': '9',
#    'police_district': 'D14',
#    'neighborhood': 'Allston / Brighton',
#    'neighborhood_services_district': '15',
#    'ward': 'Ward 22',
#    'precinct': '2211',
#    'location_zipcode': '02135',
#    'latitude': 42.35588964575996,
#    'longitude': -71.15486066893146,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0002199074074074074,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 38,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295636,
#    'open_dt': '2011-07-01T03:44:54Z',
#    'sla_target_dt': '2011-07-04T03:44:53Z',
#    'closed_dt': '2011-07-01T05:19:44Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Pick up Dead Animal',
#    'subject': 'Public Works Department',
#    'reason': 'Street Cleaning',
#    'type': 'Pick up Dead Animal',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '4',
#    'police_district': 'B3',
#    'neighborhood': 'Greater Mattapan',
#    'neighborhood_services_district': '9',
#    'ward': 'Ward 18',
#    'precinct': '1801',
#    'location_zipcode': '02126',
#    'latitude': 42.27068956201494,
#    'longitude': -71.08337069946938,
#    'source': 'Constituent Call',
#    'resolution_time': 0.06585648148148149,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 44,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295637,
#    'open_dt': '2011-07-01T03:51:13Z',
#    'sla_target_dt': '2011-07-05T03:51:11Z',
#    'closed_dt': '2011-07-01T03:51:41Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '11',
#    'pwd_district': '04',
#    'city_council_district': '9',
#    'police_district': 'D14',
#    'neighborhood': 'Allston / Brighton',
#    'neighborhood_services_district': '15',
#    'ward': 'Ward 22',
#    'precinct': '2211',
#    'location_zipcode': '02135',
#    'latitude': 42.35639965522054,
#    'longitude': -71.16205068407533,
#    'source': 'Employee Generated',
#    'resolution_time': 0.00032407407407407406,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 51,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295638,
#    'open_dt': '2011-07-01T03:57:58Z',
#    'sla_target_dt': '2011-09-02T03:57:58Z',
#    'closed_dt': None,
#    'on_time': 'OVERDUE',
#    'case_status': 'Open',
#    'closure_reason': 'empty',
#    'case_title': 'Graffiti: Ward 10  1009  Other',
#    'subject': 'Property Management',
#    'reason': 'Graffiti',
#    'type': 'Graffiti Removal',
#    'queue': 'INFO01_GenericeFormforOtherServiceRequestTypes',
#    'department': 'INFO',
#    'fire_district': '9',
#    'pwd_district': '02',
#    'city_council_district': '6',
#    'police_district': 'E13',
#    'neighborhood': 'Jamaica Plain',
#    'neighborhood_services_district': '11',
#    'ward': '10',
#    'precinct': '1009',
#    'location_zipcode': '02130',
#    'latitude': 42.32177624931921,
#    'longitude': -71.10583941410174,
#    'source': 'Citizens Connect App',
#    'resolution_time': nan,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 57,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295639,
#    'open_dt': '2011-07-01T04:02:09Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:02:10Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '4',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '8',
#    'ward': 'Ward 17',
#    'precinct': '1711',
#    'location_zipcode': '02124',
#    'latitude': 42.284375537071234,
#    'longitude': -71.06625362993721,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 2,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295640,
#    'open_dt': '2011-07-01T04:02:21Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:02:22Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '4',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '8',
#    'ward': 'Ward 17',
#    'precinct': '1711',
#    'location_zipcode': '02124',
#    'latitude': 42.2841995395202,
#    'longitude': -71.06801063434634,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 2,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295641,
#    'open_dt': '2011-07-01T04:02:37Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:02:38Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1611',
#    'location_zipcode': '02124',
#    'latitude': 42.27525953315453,
#    'longitude': -71.06307064296834,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 2,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295642,
#    'open_dt': '2011-07-01T04:02:51Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:02:52Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1611',
#    'location_zipcode': '02124',
#    'latitude': 42.27522953381212,
#    'longitude': -71.06324064316154,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 2,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295643,
#    'open_dt': '2011-07-01T04:03:09Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:03:09Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1606',
#    'location_zipcode': '02124',
#    'latitude': 42.286929532516105,
#    'longitude': -71.06325061737272,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 3,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295644,
#    'open_dt': '2011-07-01T04:03:22Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:03:22Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1606',
#    'location_zipcode': '02124',
#    'latitude': 42.28720153268102,
#    'longitude': -71.06337261742603,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 3,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295645,
#    'open_dt': '2011-07-01T04:03:35Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:03:35Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1606',
#    'location_zipcode': '02124',
#    'latitude': 42.28958953206206,
#    'longitude': -71.06281061010341,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 3,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295646,
#    'open_dt': '2011-07-01T04:03:54Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:03:55Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1612',
#    'location_zipcode': '02124',
#    'latitude': 42.28117951357164,
#    'longitude': -71.04915059879906,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 3,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295647,
#    'open_dt': '2011-07-01T04:04:07Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:07Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1612',
#    'location_zipcode': '02124',
#    'latitude': 42.279469514795096,
#    'longitude': -71.05036060536139,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295648,
#    'open_dt': '2011-07-01T04:04:21Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:21Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 17',
#    'precinct': '1713',
#    'location_zipcode': '02124',
#    'latitude': 42.27226853697887,
#    'longitude': -71.06580065574612,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295649,
#    'open_dt': '2011-07-01T04:04:26Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:27Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 17',
#    'precinct': '1713',
#    'location_zipcode': '02124',
#    'latitude': 42.27226853697887,
#    'longitude': -71.06580065574612,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295650,
#    'open_dt': '2011-07-01T04:04:32Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:32Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 17',
#    'precinct': '1713',
#    'location_zipcode': '02124',
#    'latitude': 42.27226853697887,
#    'longitude': -71.06580065574612,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295651,
#    'open_dt': '2011-07-01T04:04:35Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:36Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 17',
#    'precinct': '1713',
#    'location_zipcode': '02124',
#    'latitude': 42.27226853697887,
#    'longitude': -71.06580065574612,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295652,
#    'open_dt': '2011-07-01T04:04:54Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:54Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1611',
#    'location_zipcode': '02124',
#    'latitude': 42.28020500714201,
#    'longitude': -71.05658147616047,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295653,
#    'open_dt': '2011-07-01T04:05:09Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:05:09Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '5',
#    'police_district': 'B3',
#    'neighborhood': 'Greater Mattapan',
#    'neighborhood_services_district': '9',
#    'ward': 'Ward 18',
#    'precinct': '1821',
#    'location_zipcode': '02126',
#    'latitude': 42.27589959155152,
#    'longitude': -71.10474073548498,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 5,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295654,
#    'open_dt': '2011-07-01T04:05:20Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:05:21Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '5',
#    'police_district': 'B3',
#    'neighborhood': 'Greater Mattapan',
#    'neighborhood_services_district': '9',
#    'ward': 'Ward 18',
#    'precinct': '1803',
#    'location_zipcode': '02126',
#    'latitude': 42.27667959262112,
#    'longitude': -71.1055907361687,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 5,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295655,
#    'open_dt': '2011-07-01T04:05:25Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:05:25Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '5',
#    'police_district': 'B3',
#    'neighborhood': 'Greater Mattapan',
#    'neighborhood_services_district': '9',
#    'ward': 'Ward 18',
#    'precinct': '1803',
#    'location_zipcode': '02126',
#    'latitude': 42.27667959262112,
#    'longitude': -71.1055907361687,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 5,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295656,
#    'open_dt': '2011-07-01T04:05:39Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:05:39Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '4',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '8',
#    'ward': 'Ward 17',
#    'precinct': '1711',
#    'location_zipcode': '02124',
#    'latitude': 42.28374954161032,
#    'longitude': -71.06952063821612,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 5,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295657,
#    'open_dt': '2011-07-01T04:05:55Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:05:56Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1612',
#    'location_zipcode': '02124',
#    'latitude': 42.28259319455202,
#    'longitude': -71.0557207937692,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 5,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295658,
#    'open_dt': '2011-07-01T04:06:05Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:06:07Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1612',
#    'location_zipcode': '02124',
#    'latitude': 42.28259319455202,
#    'longitude': -71.0557207937692,
#    'source': 'Employee Generated',
#    'resolution_time': 2.3148148148148147e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 6,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295659,
#    'open_dt': '2011-07-01T04:06:54Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:06:54Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1611',
#    'location_zipcode': '02124',
#    'latitude': 42.2808165219258,
#    'longitude': -71.05548861378948,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 6,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295660,
#    'open_dt': '2011-07-01T04:06:57Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:06:58Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1611',
#    'location_zipcode': '02124',
#    'latitude': 42.2808165219258,
#    'longitude': -71.05548861378948,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 6,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295661,
#    'open_dt': '2011-07-01T04:07:04Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:07:04Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
# ...
#    'resolution_time': nan,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 12,
#    'open_minute': 35,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296885,
#    'open_dt': '2011-07-05T12:36:29Z',
#    'sla_target_dt': '2011-07-07T12:36:29Z',
#    'closed_dt': '2011-07-06T03:15:54Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Requests for Street Cleaning',
#    'subject': 'Public Works Department',
#    'reason': 'Street Cleaning',
#    'type': 'Requests for Street Cleaning',
#    'queue': 'PWDx_District 1C: Downtown',
#    'department': 'PWDx',
#    'fire_district': '4',
#    'pwd_district': '1C',
#    'city_council_district': '8',
#    'police_district': 'D4',
#    'neighborhood': 'Back Bay',
#    'neighborhood_services_district': '14',
#    'ward': 'Ward 5',
#    'precinct': '0508',
#    'location_zipcode': '02116',
#    'latitude': 42.34968561911849,
#    'longitude': -71.08217996914497,
#    'source': 'Constituent Call',
#    'resolution_time': 0.6107060185185185,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 12,
#    'open_minute': 36,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296887,
#    'open_dt': '2011-07-05T12:49:47Z',
#    'sla_target_dt': '2011-07-07T12:49:47Z',
#    'closed_dt': '2011-07-06T03:26:42Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'invalid',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': ' ',
#    'pwd_district': ' ',
#    'city_council_district': ' ',
#    'police_district': ' ',
#    'neighborhood': 'No Neighborhood',
#    'neighborhood_services_district': ' ',
#    'ward': ' ',
#    'precinct': ' ',
#    'location_zipcode': '00000',
#    'latitude': nan,
#    'longitude': nan,
#    'source': 'Self Service',
#    'resolution_time': 0.6089699074074074,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 12,
#    'open_minute': 49,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296891,
#    'open_dt': '2011-07-05T13:03:31Z',
#    'sla_target_dt': '2011-07-13T04:30:00Z',
#    'closed_dt': '2011-07-12T04:07:18Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Contractor Complaints',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Contractor Complaints',
#    'queue': 'PWDx_Contractor Complaints',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '6',
#    'police_district': 'E5',
#    'neighborhood': 'West Roxbury',
#    'neighborhood_services_district': '12',
#    'ward': 'Ward 20',
#    'precinct': '2013',
#    'location_zipcode': '02132',
#    'latitude': 42.282079676712186,
#    'longitude': -71.16574085898603,
#    'source': 'Constituent Call',
#    'resolution_time': 6.627627314814815,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 3,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296892,
#    'open_dt': '2011-07-05T13:04:50Z',
#    'sla_target_dt': '2011-07-13T04:30:00Z',
#    'closed_dt': '2011-07-07T08:50:29Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'roa',
#    'case_title': 'Contractor Complaints',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Contractor Complaints',
#    'queue': 'PWDx_District 06: West Roxbury and Roslindale',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '6',
#    'police_district': 'E5',
#    'neighborhood': 'West Roxbury',
#    'neighborhood_services_district': '12',
#    'ward': 'Ward 20',
#    'precinct': '2017',
#    'location_zipcode': '02132',
#    'latitude': 42.28406968091335,
#    'longitude': -71.16906086215779,
#    'source': 'Constituent Call',
#    'resolution_time': 1.8233680555555556,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 4,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296893,
#    'open_dt': '2011-07-05T13:04:54Z',
#    'sla_target_dt': '2011-07-20T04:30:00Z',
#    'closed_dt': '2011-07-07T10:19:48Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Street Light Outages',
#    'subject': 'Public Works Department',
#    'reason': 'Street Lights',
#    'type': 'Street Light Outages',
#    'queue': 'PWDx_Street Light Outages',
#    'department': 'PWDx',
#    'fire_district': '3',
#    'pwd_district': '1B',
#    'city_council_district': '8',
#    'police_district': 'A1',
#    'neighborhood': 'Beacon Hill',
#    'neighborhood_services_district': '14',
#    'ward': 'Ward 5',
#    'precinct': '0503',
#    'location_zipcode': '02108',
#    'latitude': 42.35761878132067,
#    'longitude': -71.06846533329691,
#    'source': 'Constituent Call',
#    'resolution_time': 1.8853472222222223,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 4,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296894,
#    'open_dt': '2011-07-05T13:07:21Z',
#    'sla_target_dt': '2011-11-02T13:07:20Z',
#    'closed_dt': '2011-08-05T07:13:07Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'novio',
#    'case_title': 'Unsatisfactory Living Conditions',
#    'subject': 'Inspectional Services',
#    'reason': 'Housing',
#    'type': 'Unsatisfactory Living Conditions',
#    'queue': 'ISD_Housing (INTERNAL)',
#    'department': 'ISD',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1817',
#    'location_zipcode': '02136',
#    'latitude': 42.24800962543075,
#    'longitude': -71.1186508268736,
#    'source': 'Constituent Call',
#    'resolution_time': 30.75400462962963,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 7,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296895,
#    'open_dt': '2011-07-05T13:18:52Z',
#    'sla_target_dt': '2011-07-08T04:30:00Z',
#    'closed_dt': '2011-07-06T02:13:46Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '03',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 13',
#    'precinct': '1310',
#    'location_zipcode': '02125',
#    'latitude': 42.309169512681365,
#    'longitude': -71.05006053802947,
#    'source': 'Self Service',
#    'resolution_time': 0.538125,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 18,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296896,
#    'open_dt': '2011-07-05T13:38:32Z',
#    'sla_target_dt': '2011-07-08T04:30:00Z',
#    'closed_dt': '2011-07-05T13:39:11Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'invalid',
#    'case_title': 'Request for Pothole Repair',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Request for Pothole Repair',
#    'queue': 'PWDx_Requests for Pothole Repair',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1817',
#    'location_zipcode': '02136',
#    'latitude': 42.24800962543075,
#    'longitude': -71.1186508268736,
#    'source': 'Constituent Call',
#    'resolution_time': 0.00045138888888888887,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 38,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296897,
#    'open_dt': '2011-07-05T13:44:29Z',
#    'sla_target_dt': '2011-08-19T13:44:29Z',
#    'closed_dt': '2011-08-23T06:30:35Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'New Sign  Crosswalk or Pavement Marking',
#    'subject': 'Transportation - Traffic Division',
#    'reason': 'Signs & Signals',
#    'type': 'New Sign  Crosswalk or Pavement Marking',
#    'queue': 'BTDT_Engineering_New Sign and Pavement Marking Requests',
#    'department': 'BTDT',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1819',
#    'location_zipcode': '02136',
#    'latitude': 42.254300836602965,
#    'longitude': -71.13396808655195,
#    'source': 'Self Service',
#    'resolution_time': 48.698680555555555,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 44,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296902,
#    'open_dt': '2011-07-05T14:14:47Z',
#    'sla_target_dt': '2011-07-08T04:30:00Z',
#    'closed_dt': '2011-07-06T02:17:33Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '03',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 13',
#    'precinct': '1308',
#    'location_zipcode': '02125',
#    'latitude': 42.316209517522665,
#    'longitude': -71.05398053115351,
#    'source': 'Constituent Call',
#    'resolution_time': 0.5019212962962963,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 14,
#    'open_minute': 14,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296903,
#    'open_dt': '2011-07-05T14:48:52Z',
#    'sla_target_dt': '2011-07-07T04:30:00Z',
#    'closed_dt': '2011-07-07T07:03:21Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'roa',
#    'case_title': 'Tree Emergencies',
#    'subject': 'Parks & Recreation Department',
#    'reason': 'Trees',
#    'type': 'Tree Emergencies',
#    'queue': 'INFO_Reallocation From Dept',
#    'department': 'INFO',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1815',
#    'location_zipcode': '02136',
#    'latitude': 42.262859600950826,
#    'longitude': -71.10969077560803,
#    'source': 'Constituent Call',
#    'resolution_time': 1.676724537037037,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 14,
#    'open_minute': 48,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296904,
#    'open_dt': '2011-07-05T14:50:25Z',
#    'sla_target_dt': '2011-08-03T04:30:00Z',
#    'closed_dt': '2011-07-08T09:10:50Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Request for Recycling Cart',
#    'subject': 'Public Works Department',
#    'reason': 'Recycling',
#    'type': 'Request for Recycling Cart',
#    'queue': 'PWDx_Recycling',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '02',
#    'city_council_district': '6',
#    'police_district': 'E13',
#    'neighborhood': 'Jamaica Plain',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 19',
#    'precinct': '1907',
#    'location_zipcode': '02130',
#    'latitude': 42.29614960426112,
#    'longitude': -71.1157907152149,
#    'source': 'Self Service',
#    'resolution_time': 2.764178240740741,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 14,
#    'open_minute': 50,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296905,
#    'open_dt': '2011-07-05T14:55:30Z',
#    'sla_target_dt': '2011-07-08T04:30:00Z',
#    'closed_dt': '2011-07-06T10:05:37Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Sticker Request',
#    'subject': 'Public Works Department',
#    'reason': 'Recycling',
#    'type': 'Sticker Request',
#    'queue': 'PWDx_Sticker Request',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '02',
#    'city_council_district': '6',
#    'police_district': 'E13',
#    'neighborhood': 'Jamaica Plain',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 19',
#    'precinct': '1907',
#    'location_zipcode': '02130',
#    'latitude': 42.29614960426112,
#    'longitude': -71.1157907152149,
#    'source': 'Self Service',
#    'resolution_time': 0.7986921296296297,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 14,
#    'open_minute': 55,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296907,
#    'open_dt': '2011-07-05T15:11:16Z',
#    'sla_target_dt': '2011-07-08T04:30:00Z',
#    'closed_dt': '2011-07-06T02:51:03Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '5',
#    'police_district': 'E5',
#    'neighborhood': 'Roslindale',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 19',
#    'precinct': '1913',
#    'location_zipcode': '02131',
#    'latitude': 42.28622062020202,
#    'longitude': -71.12631276078213,
#    'source': 'Self Service',
#    'resolution_time': 0.48596064814814816,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 15,
#    'open_minute': 11,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296908,
#    'open_dt': '2011-07-05T15:11:21Z',
#    'sla_target_dt': '2011-07-07T04:30:00Z',
#    'closed_dt': '2011-07-06T10:47:14Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Traffic Signal Repair',
#    'subject': 'Transportation - Traffic Division',
#    'reason': 'Signs & Signals',
#    'type': 'Traffic Signal Repair',
#    'queue': 'BTDT_Traffic Signal_Repair',
#    'department': 'BTDT',
#    'fire_district': '3',
#    'pwd_district': '1C',
#    'city_council_district': '1',
#    'police_district': 'A1',
#    'neighborhood': 'Downtown / Financial District',
#    'neighborhood_services_district': '3',
#    'ward': 'Ward 3',
#    'precinct': '0306',
#    'location_zipcode': '02110',
#    'latitude': 42.35878432219486,
#    'longitude': -71.05151079296188,
#    'source': 'Constituent Call',
#    'resolution_time': 0.8165856481481482,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 15,
#    'open_minute': 11,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   ...]}

# %%
import math

target_set = set()
def check_for_invalid_floats(data):
    for item in data:
        for key, value in item.items():
            if isinstance(value, float):
                if math.isnan(value) or value == float('inf') or value == float('-inf'):
                    target_set.add(key)

check_for_invalid_floats(pbi_package)

# %%
target_set
# Out:
# {'case_title',
#  'city_council_district',
#  'fire_district',
#  'latitude',
#  'longitude',
#  'neighborhood_services_district',
#  'on_time',
#  'police_district',
#  'precinct',
#  'pwd_district',
#  'resolution_time',
#  'ward'}

# %%
# Go through each row, if a key's value is nan, inf, or -inf, set it to None
for row in pbi_package:
    for key in row.keys():
        if isinstance(row[key], float):
            if math.isnan(row[key]) or row[key] == float('inf') or row[key] == float('-inf'):
                row[key] = None

# %%
rows_request = {}
rows_request['rows'] = pbi_package
rows_request
# Out:
# {'rows': [{'case_enquiry_id': 101000295613,
#    'open_dt': '2011-06-30T21:32:33Z',
#    'sla_target_dt': '2011-07-14T21:32:32Z',
#    'closed_dt': '2011-07-01T01:06:58Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Street Light Outages',
#    'subject': 'Public Works Department',
#    'reason': 'Street Lights',
#    'type': 'Street Light Outages',
#    'queue': 'PWDx_Street Light Outages',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'B3',
#    'neighborhood': 'Greater Mattapan',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 17',
#    'precinct': '1714',
#    'location_zipcode': '02126',
#    'latitude': 42.27154416019889,
#    'longitude': -71.07722102041515,
#    'source': 'Employee Generated',
#    'resolution_time': 0.14890046296296297,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 21,
#    'open_minute': 32,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295614,
#    'open_dt': '2011-06-30T22:18:31Z',
#    'sla_target_dt': '2011-07-04T22:18:31Z',
#    'closed_dt': '2011-07-01T02:12:43Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '5',
#    'police_district': 'E5',
#    'neighborhood': 'Roslindale',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 20',
#    'precinct': '2008',
#    'location_zipcode': '02131',
#    'latitude': 42.28384964675283,
#    'longitude': -71.14474080817594,
#    'source': 'Self Service',
#    'resolution_time': 0.1626388888888889,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 22,
#    'open_minute': 18,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295615,
#    'open_dt': '2011-06-30T22:28:04Z',
#    'sla_target_dt': '2011-08-14T22:28:04Z',
#    'closed_dt': '2011-08-01T11:21:46Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'New Sign  Crosswalk or Pavement Marking',
#    'subject': 'Transportation - Traffic Division',
#    'reason': 'Signs & Signals',
#    'type': 'New Sign  Crosswalk or Pavement Marking',
#    'queue': 'BTDT_Engineering_New Sign and Pavement Marking Requests',
#    'department': 'BTDT',
#    'fire_district': None,
#    'pwd_district': '06',
#    'city_council_district': '6',
#    'police_district': 'E5',
#    'neighborhood': 'West Roxbury',
#    'neighborhood_services_district': '12',
#    'ward': 'Ward 20',
#    'precinct': '2017',
#    'location_zipcode': '02132',
#    'latitude': 42.300277970295845,
#    'longitude': -71.16980478173973,
#    'source': 'Self Service',
#    'resolution_time': 31.53729166666667,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 22,
#    'open_minute': 28,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295616,
#    'open_dt': '2011-06-30T23:03:48Z',
#    'sla_target_dt': '2011-07-14T23:03:48Z',
#    'closed_dt': '2011-07-22T12:13:45Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Street Light Outages',
#    'subject': 'Public Works Department',
#    'reason': 'Street Lights',
#    'type': 'Street Light Outages',
#    'queue': 'PWDx_Street Light_Pending_Contractor (Internal)',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1816',
#    'location_zipcode': '02136',
#    'latitude': 42.24963961259866,
#    'longitude': -71.11563081862258,
#    'source': 'Self Service',
#    'resolution_time': 21.54857638888889,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 23,
#    'open_minute': 3,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295617,
#    'open_dt': '2011-06-30T23:12:31Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T02:12:38Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Highway Maintenance',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Highway Maintenance',
#    'queue': 'PWDx_District 03: North Dorchester',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '03',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 13',
#    'precinct': '1309',
#    'location_zipcode': '02125',
#    'latitude': 42.31443571025152,
#    'longitude': -71.05687844130581,
#    'source': 'Constituent Call',
#    'resolution_time': 0.12508101851851852,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 23,
#    'open_minute': 12,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295618,
#    'open_dt': '2011-06-30T23:43:07Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-05T05:16:10Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'noted',
#    'case_title': 'Notification',
#    'subject': "Mayor's 24 Hour Hotline",
#    'reason': 'Notification',
#    'type': 'Notification',
#    'queue': 'INFO09_Current Events',
#    'department': 'INFO',
#    'fire_district': '9',
#    'pwd_district': '10A',
#    'city_council_district': '6',
#    'police_district': 'E13',
#    'neighborhood': 'Jamaica Plain',
#    'neighborhood_services_district': '11',
#    'ward': 'Ward 10',
#    'precinct': '1006',
#    'location_zipcode': '02130',
#    'latitude': 42.32428958688874,
#    'longitude': -71.10603063017552,
#    'source': 'Constituent Call',
#    'resolution_time': 4.231284722222222,
#    'open_year': 2011,
#    'open_month': 6,
#    'open_day': 30,
#    'open_hour': 23,
#    'open_minute': 43,
#    'open_dayofweek': 3,
#    'open_dayofyear': 181,
#    'open_quarter': 2},
#   {'case_enquiry_id': 101000295619,
#    'open_dt': '2011-07-01T01:35:41Z',
#    'sla_target_dt': '2011-08-15T01:35:41Z',
#    'closed_dt': '2011-10-17T08:33:28Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'noted',
#    'case_title': 'New Sign  Crosswalk or Pavement Marking',
#    'subject': 'Transportation - Traffic Division',
#    'reason': 'Signs & Signals',
#    'type': 'New Sign  Crosswalk or Pavement Marking',
#    'queue': 'BTDT_Pavement Marking_Maintenance',
#    'department': 'BTDT',
#    'fire_district': '4',
#    'pwd_district': '10A',
#    'city_council_district': '8',
#    'police_district': 'D4',
#    'neighborhood': 'Fenway / Kenmore / Audubon Circle / Longwood',
#    'neighborhood_services_district': '14',
#    'ward': 'Ward 21',
#    'precinct': '2102',
#    'location_zipcode': '02215',
#    'latitude': 42.34712657790324,
#    'longitude': -71.10333422171043,
#    'source': 'Self Service',
#    'resolution_time': 108.29012731481481,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 1,
#    'open_minute': 35,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295620,
#    'open_dt': '2011-07-01T02:24:38Z',
#    'sla_target_dt': '2011-07-15T02:24:38Z',
#    'closed_dt': '2011-08-23T06:33:03Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Street Light Outages',
#    'subject': 'Public Works Department',
#    'reason': 'Street Lights',
#    'type': 'Street Light Outages',
#    'queue': 'PWDx_Street Light_Pending_Contractor (Internal)',
#    'department': 'PWDx',
#    'fire_district': '9',
#    'pwd_district': '10B',
#    'city_council_district': '7',
#    'police_district': 'E13',
#    'neighborhood': 'Roxbury',
#    'neighborhood_services_district': '13',
#    'ward': 'Ward 11',
#    'precinct': '1103',
#    'location_zipcode': '02119',
#    'latitude': 42.31730593338646,
#    'longitude': -71.09677136472,
#    'source': 'Constituent Call',
#    'resolution_time': 53.17251157407407,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 2,
#    'open_minute': 24,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295622,
#    'open_dt': '2011-07-01T02:44:50Z',
#    'sla_target_dt': '2011-07-04T02:44:49Z',
#    'closed_dt': '2011-07-01T02:44:55Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pick up Dead Animal',
#    'subject': 'Public Works Department',
#    'reason': 'Street Cleaning',
#    'type': 'Pick up Dead Animal',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1602',
#    'location_zipcode': '02122',
#    'latitude': 42.30201951528505,
#    'longitude': -71.05191055807035,
#    'source': 'Employee Generated',
#    'resolution_time': 5.787037037037037e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 2,
#    'open_minute': 44,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295624,
#    'open_dt': '2011-07-01T02:50:25Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T02:50:29Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Highway Maintenance',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Highway Maintenance',
#    'queue': 'PWDx_District 03: North Dorchester',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '03',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 13',
#    'precinct': '1309',
#    'location_zipcode': '02125',
#    'latitude': 42.3145335217776,
#    'longitude': -71.05705354143386,
#    'source': 'Employee Generated',
#    'resolution_time': 4.6296296296296294e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 2,
#    'open_minute': 50,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295625,
#    'open_dt': '2011-07-01T02:55:10Z',
#    'sla_target_dt': '2011-07-05T02:55:10Z',
#    'closed_dt': '2011-07-05T05:42:04Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Sticker Request',
#    'subject': 'Public Works Department',
#    'reason': 'Recycling',
#    'type': 'Sticker Request',
#    'queue': 'PWDx_Sticker Request',
#    'department': 'PWDx',
#    'fire_district': '6',
#    'pwd_district': '05',
#    'city_council_district': '2',
#    'police_district': 'C6',
#    'neighborhood': 'South Boston / South Boston Waterfront',
#    'neighborhood_services_district': '5',
#    'ward': 'Ward 7',
#    'precinct': '0701',
#    'location_zipcode': '02127',
#    'latitude': 42.33045249395599,
#    'longitude': -71.03708646139529,
#    'source': 'Self Service',
#    'resolution_time': 4.1159027777777775,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 2,
#    'open_minute': 55,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295627,
#    'open_dt': '2011-07-01T03:14:36Z',
#    'sla_target_dt': '2011-07-05T03:14:36Z',
#    'closed_dt': '2011-07-11T08:13:25Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Utility Call-In',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Utility Call-In',
#    'queue': 'PWDx_Utility Call-In',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1817',
#    'location_zipcode': '02136',
#    'latitude': 42.24487964311917,
#    'longitude': -71.12043083413081,
#    'source': 'Constituent Call',
#    'resolution_time': 10.207511574074074,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 14,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295628,
#    'open_dt': '2011-07-01T03:16:44Z',
#    'sla_target_dt': '2011-07-31T03:16:44Z',
#    'closed_dt': '2011-07-08T06:44:08Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'vioiss',
#    'case_title': 'Rodent Activity',
#    'subject': 'Inspectional Services',
#    'reason': 'Environmental Services',
#    'type': 'Rodent Activity',
#    'queue': 'ISD_Environmental Services (INTERNAL)',
#    'department': 'ISD',
#    'fire_district': '4',
#    'pwd_district': '1C',
#    'city_council_district': '2',
#    'police_district': 'A1',
#    'neighborhood': 'Back Bay',
#    'neighborhood_services_district': '6',
#    'ward': 'Ward 5',
#    'precinct': '0501',
#    'location_zipcode': '02116',
#    'latitude': 42.34874753263342,
#    'longitude': -71.0674934886141,
#    'source': 'Constituent Call',
#    'resolution_time': 7.144027777777778,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 16,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295629,
#    'open_dt': '2011-07-01T03:28:09Z',
#    'sla_target_dt': '2011-07-05T03:28:08Z',
#    'closed_dt': '2011-07-08T06:26:28Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Sidewalk Repair (Make Safe)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Sidewalk Repair (Make Safe)',
#    'queue': 'PWDx_Highway Construction',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '6',
#    'police_district': 'E5',
#    'neighborhood': 'West Roxbury',
#    'neighborhood_services_district': '12',
#    'ward': 'Ward 20',
#    'precinct': '2017',
#    'location_zipcode': '02132',
#    'latitude': 42.28759087384675,
#    'longitude': -71.16863452256548,
#    'source': 'Constituent Call',
#    'resolution_time': 7.123831018518518,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 28,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295630,
#    'open_dt': '2011-07-01T03:31:50Z',
#    'sla_target_dt': '2011-07-05T03:31:46Z',
#    'closed_dt': '2011-07-01T08:00:42Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Missed Recycling: District 06',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Missed Trash/Recycling/Yard Waste/Bulk Item',
#    'queue': 'PWDx_Missed Trash\\Recycling\\Yard Waste\\Bulk Item',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '5',
#    'police_district': 'E5',
#    'neighborhood': 'Roslindale',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1810',
#    'location_zipcode': '02131',
#    'latitude': 42.28184962688987,
#    'longitude': -71.13060078096619,
#    'source': 'Employee Generated',
#    'resolution_time': 0.18671296296296297,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 31,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295631,
#    'open_dt': '2011-07-01T03:33:45Z',
#    'sla_target_dt': '2011-07-05T03:33:44Z',
#    'closed_dt': '2011-07-01T03:42:58Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'invalid',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '10B',
#    'city_council_district': '7',
#    'police_district': 'B2',
#    'neighborhood': 'Roxbury',
#    'neighborhood_services_district': '13',
#    'ward': 'Ward 9',
#    'precinct': '0905',
#    'location_zipcode': '02119',
#    'latitude': 42.327909564852966,
#    'longitude': -71.08997058599672,
#    'source': 'Employee Generated',
#    'resolution_time': 0.006400462962962963,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 33,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295632,
#    'open_dt': '2011-07-01T03:34:19Z',
#    'sla_target_dt': '2011-07-29T03:34:16Z',
#    'closed_dt': '2011-07-22T11:43:34Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Request for Recycling Cart',
#    'subject': 'Public Works Department',
#    'reason': 'Recycling',
#    'type': 'Request for Recycling Cart',
#    'queue': 'PWDx_Recycling',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '10B',
#    'city_council_district': '7',
#    'police_district': 'B2',
#    'neighborhood': 'Roxbury',
#    'neighborhood_services_district': '13',
#    'ward': 'Ward 9',
#    'precinct': '0905',
#    'location_zipcode': '02119',
#    'latitude': 42.327909564852966,
#    'longitude': -71.08997058599672,
#    'source': 'Employee Generated',
#    'resolution_time': 21.339756944444446,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 34,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295633,
#    'open_dt': '2011-07-01T03:36:03Z',
#    'sla_target_dt': '2011-07-05T03:36:02Z',
#    'closed_dt': '2011-07-01T03:36:43Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '9',
#    'pwd_district': '06',
#    'city_council_district': '6',
#    'police_district': 'E5',
#    'neighborhood': 'West Roxbury',
#    'neighborhood_services_district': '12',
#    'ward': 'Ward 20',
#    'precinct': '2019',
#    'location_zipcode': '02132',
#    'latitude': 42.29167965472856,
#    'longitude': -71.1520008070818,
#    'source': 'Employee Generated',
#    'resolution_time': 0.000462962962962963,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 36,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295634,
#    'open_dt': '2011-07-01T03:37:17Z',
#    'sla_target_dt': '2011-07-05T03:37:16Z',
#    'closed_dt': '2011-07-01T03:37:39Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '6',
#    'pwd_district': '05',
#    'city_council_district': '2',
#    'police_district': 'C6',
#    'neighborhood': 'South Boston / South Boston Waterfront',
#    'neighborhood_services_district': '5',
#    'ward': '06',
#    'precinct': '0606',
#    'location_zipcode': '02127',
#    'latitude': 42.334630562886446,
#    'longitude': -71.03635056820346,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0002546296296296296,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 37,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295635,
#    'open_dt': '2011-07-01T03:38:25Z',
#    'sla_target_dt': '2011-07-05T03:38:24Z',
#    'closed_dt': '2011-07-01T03:38:44Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '11',
#    'pwd_district': '04',
#    'city_council_district': '9',
#    'police_district': 'D14',
#    'neighborhood': 'Allston / Brighton',
#    'neighborhood_services_district': '15',
#    'ward': 'Ward 22',
#    'precinct': '2211',
#    'location_zipcode': '02135',
#    'latitude': 42.35588964575996,
#    'longitude': -71.15486066893146,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0002199074074074074,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 38,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295636,
#    'open_dt': '2011-07-01T03:44:54Z',
#    'sla_target_dt': '2011-07-04T03:44:53Z',
#    'closed_dt': '2011-07-01T05:19:44Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Pick up Dead Animal',
#    'subject': 'Public Works Department',
#    'reason': 'Street Cleaning',
#    'type': 'Pick up Dead Animal',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '4',
#    'police_district': 'B3',
#    'neighborhood': 'Greater Mattapan',
#    'neighborhood_services_district': '9',
#    'ward': 'Ward 18',
#    'precinct': '1801',
#    'location_zipcode': '02126',
#    'latitude': 42.27068956201494,
#    'longitude': -71.08337069946938,
#    'source': 'Constituent Call',
#    'resolution_time': 0.06585648148148149,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 44,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295637,
#    'open_dt': '2011-07-01T03:51:13Z',
#    'sla_target_dt': '2011-07-05T03:51:11Z',
#    'closed_dt': '2011-07-01T03:51:41Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '11',
#    'pwd_district': '04',
#    'city_council_district': '9',
#    'police_district': 'D14',
#    'neighborhood': 'Allston / Brighton',
#    'neighborhood_services_district': '15',
#    'ward': 'Ward 22',
#    'precinct': '2211',
#    'location_zipcode': '02135',
#    'latitude': 42.35639965522054,
#    'longitude': -71.16205068407533,
#    'source': 'Employee Generated',
#    'resolution_time': 0.00032407407407407406,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 51,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295638,
#    'open_dt': '2011-07-01T03:57:58Z',
#    'sla_target_dt': '2011-09-02T03:57:58Z',
#    'closed_dt': None,
#    'on_time': 'OVERDUE',
#    'case_status': 'Open',
#    'closure_reason': 'empty',
#    'case_title': 'Graffiti: Ward 10  1009  Other',
#    'subject': 'Property Management',
#    'reason': 'Graffiti',
#    'type': 'Graffiti Removal',
#    'queue': 'INFO01_GenericeFormforOtherServiceRequestTypes',
#    'department': 'INFO',
#    'fire_district': '9',
#    'pwd_district': '02',
#    'city_council_district': '6',
#    'police_district': 'E13',
#    'neighborhood': 'Jamaica Plain',
#    'neighborhood_services_district': '11',
#    'ward': '10',
#    'precinct': '1009',
#    'location_zipcode': '02130',
#    'latitude': 42.32177624931921,
#    'longitude': -71.10583941410174,
#    'source': 'Citizens Connect App',
#    'resolution_time': None,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 3,
#    'open_minute': 57,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295639,
#    'open_dt': '2011-07-01T04:02:09Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:02:10Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '4',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '8',
#    'ward': 'Ward 17',
#    'precinct': '1711',
#    'location_zipcode': '02124',
#    'latitude': 42.284375537071234,
#    'longitude': -71.06625362993721,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 2,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295640,
#    'open_dt': '2011-07-01T04:02:21Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:02:22Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '4',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '8',
#    'ward': 'Ward 17',
#    'precinct': '1711',
#    'location_zipcode': '02124',
#    'latitude': 42.2841995395202,
#    'longitude': -71.06801063434634,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 2,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295641,
#    'open_dt': '2011-07-01T04:02:37Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:02:38Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1611',
#    'location_zipcode': '02124',
#    'latitude': 42.27525953315453,
#    'longitude': -71.06307064296834,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 2,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295642,
#    'open_dt': '2011-07-01T04:02:51Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:02:52Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1611',
#    'location_zipcode': '02124',
#    'latitude': 42.27522953381212,
#    'longitude': -71.06324064316154,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 2,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295643,
#    'open_dt': '2011-07-01T04:03:09Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:03:09Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1606',
#    'location_zipcode': '02124',
#    'latitude': 42.286929532516105,
#    'longitude': -71.06325061737272,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 3,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295644,
#    'open_dt': '2011-07-01T04:03:22Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:03:22Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1606',
#    'location_zipcode': '02124',
#    'latitude': 42.28720153268102,
#    'longitude': -71.06337261742603,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 3,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295645,
#    'open_dt': '2011-07-01T04:03:35Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:03:35Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1606',
#    'location_zipcode': '02124',
#    'latitude': 42.28958953206206,
#    'longitude': -71.06281061010341,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 3,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295646,
#    'open_dt': '2011-07-01T04:03:54Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:03:55Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1612',
#    'location_zipcode': '02124',
#    'latitude': 42.28117951357164,
#    'longitude': -71.04915059879906,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 3,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295647,
#    'open_dt': '2011-07-01T04:04:07Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:07Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1612',
#    'location_zipcode': '02124',
#    'latitude': 42.279469514795096,
#    'longitude': -71.05036060536139,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295648,
#    'open_dt': '2011-07-01T04:04:21Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:21Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 17',
#    'precinct': '1713',
#    'location_zipcode': '02124',
#    'latitude': 42.27226853697887,
#    'longitude': -71.06580065574612,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295649,
#    'open_dt': '2011-07-01T04:04:26Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:27Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 17',
#    'precinct': '1713',
#    'location_zipcode': '02124',
#    'latitude': 42.27226853697887,
#    'longitude': -71.06580065574612,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295650,
#    'open_dt': '2011-07-01T04:04:32Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:32Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 17',
#    'precinct': '1713',
#    'location_zipcode': '02124',
#    'latitude': 42.27226853697887,
#    'longitude': -71.06580065574612,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295651,
#    'open_dt': '2011-07-01T04:04:35Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:36Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 17',
#    'precinct': '1713',
#    'location_zipcode': '02124',
#    'latitude': 42.27226853697887,
#    'longitude': -71.06580065574612,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295652,
#    'open_dt': '2011-07-01T04:04:54Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:04:54Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1611',
#    'location_zipcode': '02124',
#    'latitude': 42.28020500714201,
#    'longitude': -71.05658147616047,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 4,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295653,
#    'open_dt': '2011-07-01T04:05:09Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:05:09Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '5',
#    'police_district': 'B3',
#    'neighborhood': 'Greater Mattapan',
#    'neighborhood_services_district': '9',
#    'ward': 'Ward 18',
#    'precinct': '1821',
#    'location_zipcode': '02126',
#    'latitude': 42.27589959155152,
#    'longitude': -71.10474073548498,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 5,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295654,
#    'open_dt': '2011-07-01T04:05:20Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:05:21Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '5',
#    'police_district': 'B3',
#    'neighborhood': 'Greater Mattapan',
#    'neighborhood_services_district': '9',
#    'ward': 'Ward 18',
#    'precinct': '1803',
#    'location_zipcode': '02126',
#    'latitude': 42.27667959262112,
#    'longitude': -71.1055907361687,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 5,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295655,
#    'open_dt': '2011-07-01T04:05:25Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:05:25Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '5',
#    'police_district': 'B3',
#    'neighborhood': 'Greater Mattapan',
#    'neighborhood_services_district': '9',
#    'ward': 'Ward 18',
#    'precinct': '1803',
#    'location_zipcode': '02126',
#    'latitude': 42.27667959262112,
#    'longitude': -71.1055907361687,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 5,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295656,
#    'open_dt': '2011-07-01T04:05:39Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:05:39Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '4',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '8',
#    'ward': 'Ward 17',
#    'precinct': '1711',
#    'location_zipcode': '02124',
#    'latitude': 42.28374954161032,
#    'longitude': -71.06952063821612,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 5,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295657,
#    'open_dt': '2011-07-01T04:05:55Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:05:56Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1612',
#    'location_zipcode': '02124',
#    'latitude': 42.28259319455202,
#    'longitude': -71.0557207937692,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 5,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295658,
#    'open_dt': '2011-07-01T04:06:05Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:06:07Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1612',
#    'location_zipcode': '02124',
#    'latitude': 42.28259319455202,
#    'longitude': -71.0557207937692,
#    'source': 'Employee Generated',
#    'resolution_time': 2.3148148148148147e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 6,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295659,
#    'open_dt': '2011-07-01T04:06:54Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:06:54Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1611',
#    'location_zipcode': '02124',
#    'latitude': 42.2808165219258,
#    'longitude': -71.05548861378948,
#    'source': 'Employee Generated',
#    'resolution_time': 0.0,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 6,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295660,
#    'open_dt': '2011-07-01T04:06:57Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:06:58Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 16',
#    'precinct': '1611',
#    'location_zipcode': '02124',
#    'latitude': 42.2808165219258,
#    'longitude': -71.05548861378948,
#    'source': 'Employee Generated',
#    'resolution_time': 1.1574074074074073e-05,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 1,
#    'open_hour': 4,
#    'open_minute': 6,
#    'open_dayofweek': 4,
#    'open_dayofyear': 182,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000295661,
#    'open_dt': '2011-07-01T04:07:04Z',
#    'sla_target_dt': None,
#    'closed_dt': '2011-07-01T04:07:04Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'internal case',
#    'case_title': 'Pothole Repair (Internal)',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Pothole Repair (Internal)',
#    'queue': 'PWDx_District 07: South Dorchester',
#    'department': 'PWDx',
#    'fire_district': '8',
#    'pwd_district': '07',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
# ...
#    'resolution_time': None,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 12,
#    'open_minute': 35,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296885,
#    'open_dt': '2011-07-05T12:36:29Z',
#    'sla_target_dt': '2011-07-07T12:36:29Z',
#    'closed_dt': '2011-07-06T03:15:54Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Requests for Street Cleaning',
#    'subject': 'Public Works Department',
#    'reason': 'Street Cleaning',
#    'type': 'Requests for Street Cleaning',
#    'queue': 'PWDx_District 1C: Downtown',
#    'department': 'PWDx',
#    'fire_district': '4',
#    'pwd_district': '1C',
#    'city_council_district': '8',
#    'police_district': 'D4',
#    'neighborhood': 'Back Bay',
#    'neighborhood_services_district': '14',
#    'ward': 'Ward 5',
#    'precinct': '0508',
#    'location_zipcode': '02116',
#    'latitude': 42.34968561911849,
#    'longitude': -71.08217996914497,
#    'source': 'Constituent Call',
#    'resolution_time': 0.6107060185185185,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 12,
#    'open_minute': 36,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296887,
#    'open_dt': '2011-07-05T12:49:47Z',
#    'sla_target_dt': '2011-07-07T12:49:47Z',
#    'closed_dt': '2011-07-06T03:26:42Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'invalid',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': ' ',
#    'pwd_district': ' ',
#    'city_council_district': ' ',
#    'police_district': ' ',
#    'neighborhood': 'No Neighborhood',
#    'neighborhood_services_district': ' ',
#    'ward': ' ',
#    'precinct': ' ',
#    'location_zipcode': '00000',
#    'latitude': None,
#    'longitude': None,
#    'source': 'Self Service',
#    'resolution_time': 0.6089699074074074,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 12,
#    'open_minute': 49,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296891,
#    'open_dt': '2011-07-05T13:03:31Z',
#    'sla_target_dt': '2011-07-13T04:30:00Z',
#    'closed_dt': '2011-07-12T04:07:18Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Contractor Complaints',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Contractor Complaints',
#    'queue': 'PWDx_Contractor Complaints',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '6',
#    'police_district': 'E5',
#    'neighborhood': 'West Roxbury',
#    'neighborhood_services_district': '12',
#    'ward': 'Ward 20',
#    'precinct': '2013',
#    'location_zipcode': '02132',
#    'latitude': 42.282079676712186,
#    'longitude': -71.16574085898603,
#    'source': 'Constituent Call',
#    'resolution_time': 6.627627314814815,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 3,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296892,
#    'open_dt': '2011-07-05T13:04:50Z',
#    'sla_target_dt': '2011-07-13T04:30:00Z',
#    'closed_dt': '2011-07-07T08:50:29Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'roa',
#    'case_title': 'Contractor Complaints',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Contractor Complaints',
#    'queue': 'PWDx_District 06: West Roxbury and Roslindale',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '6',
#    'police_district': 'E5',
#    'neighborhood': 'West Roxbury',
#    'neighborhood_services_district': '12',
#    'ward': 'Ward 20',
#    'precinct': '2017',
#    'location_zipcode': '02132',
#    'latitude': 42.28406968091335,
#    'longitude': -71.16906086215779,
#    'source': 'Constituent Call',
#    'resolution_time': 1.8233680555555556,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 4,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296893,
#    'open_dt': '2011-07-05T13:04:54Z',
#    'sla_target_dt': '2011-07-20T04:30:00Z',
#    'closed_dt': '2011-07-07T10:19:48Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Street Light Outages',
#    'subject': 'Public Works Department',
#    'reason': 'Street Lights',
#    'type': 'Street Light Outages',
#    'queue': 'PWDx_Street Light Outages',
#    'department': 'PWDx',
#    'fire_district': '3',
#    'pwd_district': '1B',
#    'city_council_district': '8',
#    'police_district': 'A1',
#    'neighborhood': 'Beacon Hill',
#    'neighborhood_services_district': '14',
#    'ward': 'Ward 5',
#    'precinct': '0503',
#    'location_zipcode': '02108',
#    'latitude': 42.35761878132067,
#    'longitude': -71.06846533329691,
#    'source': 'Constituent Call',
#    'resolution_time': 1.8853472222222223,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 4,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296894,
#    'open_dt': '2011-07-05T13:07:21Z',
#    'sla_target_dt': '2011-11-02T13:07:20Z',
#    'closed_dt': '2011-08-05T07:13:07Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'novio',
#    'case_title': 'Unsatisfactory Living Conditions',
#    'subject': 'Inspectional Services',
#    'reason': 'Housing',
#    'type': 'Unsatisfactory Living Conditions',
#    'queue': 'ISD_Housing (INTERNAL)',
#    'department': 'ISD',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1817',
#    'location_zipcode': '02136',
#    'latitude': 42.24800962543075,
#    'longitude': -71.1186508268736,
#    'source': 'Constituent Call',
#    'resolution_time': 30.75400462962963,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 7,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296895,
#    'open_dt': '2011-07-05T13:18:52Z',
#    'sla_target_dt': '2011-07-08T04:30:00Z',
#    'closed_dt': '2011-07-06T02:13:46Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '03',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 13',
#    'precinct': '1310',
#    'location_zipcode': '02125',
#    'latitude': 42.309169512681365,
#    'longitude': -71.05006053802947,
#    'source': 'Self Service',
#    'resolution_time': 0.538125,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 18,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296896,
#    'open_dt': '2011-07-05T13:38:32Z',
#    'sla_target_dt': '2011-07-08T04:30:00Z',
#    'closed_dt': '2011-07-05T13:39:11Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'invalid',
#    'case_title': 'Request for Pothole Repair',
#    'subject': 'Public Works Department',
#    'reason': 'Highway Maintenance',
#    'type': 'Request for Pothole Repair',
#    'queue': 'PWDx_Requests for Pothole Repair',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1817',
#    'location_zipcode': '02136',
#    'latitude': 42.24800962543075,
#    'longitude': -71.1186508268736,
#    'source': 'Constituent Call',
#    'resolution_time': 0.00045138888888888887,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 38,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296897,
#    'open_dt': '2011-07-05T13:44:29Z',
#    'sla_target_dt': '2011-08-19T13:44:29Z',
#    'closed_dt': '2011-08-23T06:30:35Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'New Sign  Crosswalk or Pavement Marking',
#    'subject': 'Transportation - Traffic Division',
#    'reason': 'Signs & Signals',
#    'type': 'New Sign  Crosswalk or Pavement Marking',
#    'queue': 'BTDT_Engineering_New Sign and Pavement Marking Requests',
#    'department': 'BTDT',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1819',
#    'location_zipcode': '02136',
#    'latitude': 42.254300836602965,
#    'longitude': -71.13396808655195,
#    'source': 'Self Service',
#    'resolution_time': 48.698680555555555,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 13,
#    'open_minute': 44,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296902,
#    'open_dt': '2011-07-05T14:14:47Z',
#    'sla_target_dt': '2011-07-08T04:30:00Z',
#    'closed_dt': '2011-07-06T02:17:33Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '7',
#    'pwd_district': '03',
#    'city_council_district': '3',
#    'police_district': 'C11',
#    'neighborhood': 'Dorchester',
#    'neighborhood_services_district': '7',
#    'ward': 'Ward 13',
#    'precinct': '1308',
#    'location_zipcode': '02125',
#    'latitude': 42.316209517522665,
#    'longitude': -71.05398053115351,
#    'source': 'Constituent Call',
#    'resolution_time': 0.5019212962962963,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 14,
#    'open_minute': 14,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296903,
#    'open_dt': '2011-07-05T14:48:52Z',
#    'sla_target_dt': '2011-07-07T04:30:00Z',
#    'closed_dt': '2011-07-07T07:03:21Z',
#    'on_time': 'OVERDUE',
#    'case_status': 'Closed',
#    'closure_reason': 'roa',
#    'case_title': 'Tree Emergencies',
#    'subject': 'Parks & Recreation Department',
#    'reason': 'Trees',
#    'type': 'Tree Emergencies',
#    'queue': 'INFO_Reallocation From Dept',
#    'department': 'INFO',
#    'fire_district': '12',
#    'pwd_district': '08',
#    'city_council_district': '5',
#    'police_district': 'E18',
#    'neighborhood': 'Hyde Park',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 18',
#    'precinct': '1815',
#    'location_zipcode': '02136',
#    'latitude': 42.262859600950826,
#    'longitude': -71.10969077560803,
#    'source': 'Constituent Call',
#    'resolution_time': 1.676724537037037,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 14,
#    'open_minute': 48,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296904,
#    'open_dt': '2011-07-05T14:50:25Z',
#    'sla_target_dt': '2011-08-03T04:30:00Z',
#    'closed_dt': '2011-07-08T09:10:50Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Request for Recycling Cart',
#    'subject': 'Public Works Department',
#    'reason': 'Recycling',
#    'type': 'Request for Recycling Cart',
#    'queue': 'PWDx_Recycling',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '02',
#    'city_council_district': '6',
#    'police_district': 'E13',
#    'neighborhood': 'Jamaica Plain',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 19',
#    'precinct': '1907',
#    'location_zipcode': '02130',
#    'latitude': 42.29614960426112,
#    'longitude': -71.1157907152149,
#    'source': 'Self Service',
#    'resolution_time': 2.764178240740741,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 14,
#    'open_minute': 50,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296905,
#    'open_dt': '2011-07-05T14:55:30Z',
#    'sla_target_dt': '2011-07-08T04:30:00Z',
#    'closed_dt': '2011-07-06T10:05:37Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Sticker Request',
#    'subject': 'Public Works Department',
#    'reason': 'Recycling',
#    'type': 'Sticker Request',
#    'queue': 'PWDx_Sticker Request',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '02',
#    'city_council_district': '6',
#    'police_district': 'E13',
#    'neighborhood': 'Jamaica Plain',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 19',
#    'precinct': '1907',
#    'location_zipcode': '02130',
#    'latitude': 42.29614960426112,
#    'longitude': -71.1157907152149,
#    'source': 'Self Service',
#    'resolution_time': 0.7986921296296297,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 14,
#    'open_minute': 55,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296907,
#    'open_dt': '2011-07-05T15:11:16Z',
#    'sla_target_dt': '2011-07-08T04:30:00Z',
#    'closed_dt': '2011-07-06T02:51:03Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'closed',
#    'case_title': 'Schedule a Bulk Item Pickup',
#    'subject': 'Public Works Department',
#    'reason': 'Sanitation',
#    'type': 'Schedule a Bulk Item Pickup',
#    'queue': 'PWDx_Schedule a Bulk Item Pickup',
#    'department': 'PWDx',
#    'fire_district': '12',
#    'pwd_district': '06',
#    'city_council_district': '5',
#    'police_district': 'E5',
#    'neighborhood': 'Roslindale',
#    'neighborhood_services_district': '10',
#    'ward': 'Ward 19',
#    'precinct': '1913',
#    'location_zipcode': '02131',
#    'latitude': 42.28622062020202,
#    'longitude': -71.12631276078213,
#    'source': 'Self Service',
#    'resolution_time': 0.48596064814814816,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 15,
#    'open_minute': 11,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   {'case_enquiry_id': 101000296908,
#    'open_dt': '2011-07-05T15:11:21Z',
#    'sla_target_dt': '2011-07-07T04:30:00Z',
#    'closed_dt': '2011-07-06T10:47:14Z',
#    'on_time': 'ONTIME',
#    'case_status': 'Closed',
#    'closure_reason': 'resolved',
#    'case_title': 'Traffic Signal Repair',
#    'subject': 'Transportation - Traffic Division',
#    'reason': 'Signs & Signals',
#    'type': 'Traffic Signal Repair',
#    'queue': 'BTDT_Traffic Signal_Repair',
#    'department': 'BTDT',
#    'fire_district': '3',
#    'pwd_district': '1C',
#    'city_council_district': '1',
#    'police_district': 'A1',
#    'neighborhood': 'Downtown / Financial District',
#    'neighborhood_services_district': '3',
#    'ward': 'Ward 3',
#    'precinct': '0306',
#    'location_zipcode': '02110',
#    'latitude': 42.35878432219486,
#    'longitude': -71.05151079296188,
#    'source': 'Constituent Call',
#    'resolution_time': 0.8165856481481482,
#    'open_year': 2011,
#    'open_month': 7,
#    'open_day': 5,
#    'open_hour': 15,
#    'open_minute': 11,
#    'open_dayofweek': 1,
#    'open_dayofyear': 186,
#    'open_quarter': 3},
#   ...]}

# %%
def chunk_data(data, size):
    """Split data into chunks."""
    return [data[i:i+size] for i in range(0, len(data), size)]

# Define the chunk size
CHUNK_SIZE = 10000  # This can be adjusted based on your needs

# Split the pbi_package into chunks
chunks = chunk_data(pbi_package, CHUNK_SIZE)

# %%
successful_chunks = []
failed_chunks = list(range(len(chunks)))

# %%
# post 100 chunks one by one, 
# Then cool down for 1 hour 
# Then post the next 100 chunks one by one
import time 
counter = 0 
print(f"Chunks remaining: {len(failed_chunks)}")
print(f"Chunks completed: {len(successful_chunks)}")
while failed_chunks:
    current_chunk_idx = failed_chunks.pop(0)
    current_chunk = chunks[current_chunk_idx]
    rows_request = {'rows': chunks[current_chunk_idx]}
    try:
        response = powerBIPostRows(group_id, dataset_id, table_name, rows_request, token)
        if response.status_code == 200:
            successful_chunks.append(current_chunk_idx)
            counter += 1
        else:
            raise Exception(f"Failed to send chunk {current_chunk_idx + 1} due to: {response.text}")
    except Exception as e:
        print(e)
        print(f"length of failed_chunks: {len(failed_chunks)}")
        failed_chunks.append(current_chunk_idx)
        print(f"length of failed_chunks: {len(failed_chunks)}")
        try:
            if "Request is blocked by the upstream service until:" in e.args[0]:
                date_string = e.args[0].split(" until: ")[1]
                date_string = date_string.rstrip("}")
                date_string = date_string.replace('"', '')  # remove inner quotation marks
                print("Rate limited until " + date_string)
                # Sleep until date in error message
                sleep_until = parser.parse(date_string)
                sleep_duration = sleep_until - datetime.now()
                print(f"Sleeping for {sleep_duration.total_seconds()//3600} hours")
                time.sleep(sleep_duration.total_seconds())
            elif "Access token has expired" in e.args[0]:
                app.acquire_token_for_client(scopes=scope)
                token = result['access_token']
        except Exception as inner_exception:
            print(f"Error while processing exception: {inner_exception}")
            continue

    if counter % 100 == 0:
        print(f"Sleeping for 1 hour at {datetime.now()}")
        print(f"Chunks remaining: {len(failed_chunks)}")
        print(f"Chunks completed: {len(successful_chunks)}")
        break
# Out:
# Chunks remaining: 7
# Chunks completed: 264

# %%
# update failed chunks, by removing the successful chunks
failed_chunks = list(set(failed_chunks) - set(successful_chunks))
print(f"Chunks remaining: {len(failed_chunks)}")
print(f"Chunks completed: {len(successful_chunks)}")
# print total
print(f"Total chunks: {len(chunks)}")
# Out:
# Chunks remaining: 107
# Chunks completed: 164
# Total chunks: 271

# %%
failed_chunks.append(current_chunk_idx)
